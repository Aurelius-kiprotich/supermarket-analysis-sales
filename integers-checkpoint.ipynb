# %%
x=4
y=8
z=x+y
print(z)
# Out:
# 12

# %%
x=7
y=6
z=x-y
print(z)
# Out:
# 1

# %%
x=9
y=3
z=x*y
print(z)
# Out:
# 27

# %%
x=9
y=3
z=x/y
print(z)
# Out:
# 3.0

# %%
x=9
y=2
z=x**y
print(z)
# Out:
# 81

# %%
a=250
b=3
c=9
d=10
e=5
f=a*b
g=f/9
h=d+e
i=f*g
j=i/h
print(j)
# Out:
# 4166.666666666667

# %%
a=250
b=3
c=9
d=10
e=5
f=a*b
g=f/9
h=d+e
i=f*g/h
print(i)
# Out:
# 4166.666666666667

# %%
a=250
b=3
c=9
d=10
e=5
f=a*b
g=f/c
h=d+e
i=f*g/h
print(i)
"not working"
# Out:
# 4166.666666666667

# %%
a=250
b=3
c=9
d=10
e=5
f=a*b/c
g=d+e
h=f/g
print(h)
# Out:
# 5.555555555555555

# %%
a=100
b=20
c=75
d=a+74*b
print(d)
# Out:
# 1580

# %%
a=1580
b=0.2
c=a*b
print(c)
# Out:
# 316.0

# %%
perkm=20
dist=75
bfare=100
x=dist-1
y=x*perkm
fare=y+100
print(fare)
# Out:
# 1580

# %%
comm=20/100
dprice=fare*comm
print(dprice)
# Out:
# 316.0
